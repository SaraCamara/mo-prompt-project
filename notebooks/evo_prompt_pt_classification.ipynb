# %% [markdown]
# ## EVO-Prompt Sentiment Classification (Portuguese - imdb_pt)
# ### Etapas: População inicial, avaliação, evolução, repetição

# %% [markdown]
# ### Configuração do Ambiente

# %%
# %pip install datasets
# %pip install openai==0.28.0
# %pip install maritalk
# %pip install numpy
# %pip install scikit-learn
# %pip install scipy
# %pip install seaborn
# %pip install matplotlib
# %pip install pandas
# %pip install sklearn
# %pip install random
# %pip install requests
# %pip install logging
# %pip install time
# Out:
# Requirement already satisfied: datasets in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (3.3.2)
# Requirement already satisfied: filelock in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (3.17.0)
# Requirement already satisfied: numpy>=1.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: pyarrow>=15.0.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (19.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.32.2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2024.12.0,>=2023.1.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets) (2024.12.0)
# Requirement already satisfied: aiohttp in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (3.11.13)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (0.29.2)
# Requirement already satisfied: packaging in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->datasets) (1.18.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from huggingface-hub>=0.24.0->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas->datasets) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai==0.28.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (0.28.0)
# Requirement already satisfied: requests>=2.20 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from openai==0.28.0) (2.32.3)
# Requirement already satisfied: tqdm in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from openai==0.28.0) (4.67.1)
# Requirement already satisfied: aiohttp in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from openai==0.28.0) (3.11.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.20->openai==0.28.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.20->openai==0.28.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.20->openai==0.28.0) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests>=2.20->openai==0.28.0) (2025.1.31)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (2.5.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (25.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (0.3.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from aiohttp->openai==0.28.0) (1.18.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: maritalk in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (0.2.6)
# Requirement already satisfied: requests in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from maritalk) (2.32.3)
# Requirement already satisfied: tqdm in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from maritalk) (4.67.1)
# Requirement already satisfied: httpx in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from maritalk) (0.28.1)
# Requirement already satisfied: tiktoken<0.8,>=0.7 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from maritalk) (0.7.0)
# Requirement already satisfied: transformers in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from maritalk) (4.50.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from tiktoken<0.8,>=0.7->maritalk) (2024.11.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests->maritalk) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests->maritalk) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests->maritalk) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests->maritalk) (2025.1.31)
# Requirement already satisfied: anyio in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from httpx->maritalk) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from httpx->maritalk) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx->maritalk) (0.14.0)
# Requirement already satisfied: filelock in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (3.17.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.26.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (0.29.2)
# Requirement already satisfied: numpy>=1.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (6.0.2)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from transformers->maritalk) (0.5.3)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers->maritalk) (2024.12.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from huggingface-hub<1.0,>=0.26.0->transformers->maritalk) (4.12.2)
# Requirement already satisfied: sniffio>=1.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from anyio->httpx->maritalk) (1.3.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from scikit-learn) (2.2.3)
# Requirement already satisfied: scipy>=1.6.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from scikit-learn) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (1.15.2)
# Requirement already satisfied: numpy<2.5,>=1.23.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from scipy) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: pandas>=1.2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from seaborn) (2.2.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from seaborn) (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (24.2)
# Requirement already satisfied: pillow>=8 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas>=1.2->seaborn) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (2.2.3)
# Requirement already satisfied: packaging>=20.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas) (2.2.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement random (from versions: none)
# ERROR: No matching distribution found for random
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (from requests) (2025.1.31)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: logging in /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages (0.4.9.6)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement time (from versions: none)
# ERROR: No matching distribution found for time
# Note: you may need to restart the kernel to use updated packages.

# %%
# Setup Inicial
import random
import os
import pandas as pd
import numpy as np
import requests
import json
import openai
import yaml
from sklearn.metrics import accuracy_score, f1_score

# %% [markdown]
# ## Configuração de APIs (endpoint e token)

# %%
# Carregando configurações
creds_path = os.path.expanduser("~/repos/emo-prompt-project/config/credentials.yaml")
settings_path = os.path.expanduser("~/repos/emo-prompt-project/config/experiment_settings.yaml")

with open(creds_path) as f:
    creds = yaml.safe_load(f)
with open(settings_path) as f:
    settings = yaml.safe_load(f)

# %%
openai.api_key = creds["openai_api_key"]
openai.api_base = creds["openai_api_base"]

# %%
sabia_api_key = creds["sabia_api_key"]
sabia_url = creds["sabia_url"]
sabia_headers = {
    "Authorization": f"Bearer {sabia_api_key}",
    "Content-Type": "application/json"
}

# %% [markdown]
# ## Preparação do Dataset

# %%
# Carregamento do Dataset (subconjunto local)
df = pd.read_csv("~/repos/emo-prompt-project/dataset/imdb_pt_subset1.csv")
df = df.dropna(subset=["text", "label"])
df = df[df["label"].isin([0, 1])]
texts = df["text"].tolist()
labels = df["label"].tolist()

# %%
# População Inicial de Prompts 
initial_prompts = [
    "Avalie o sentimento desta crítica de filme e classifique-a como 'positiva', 'negativa' ou 'neutra'.",
    "Determine se a opinião expressa na crítica a seguir reflete um sentimento positivo ou negativo sobre o filme.",
    "Classifique o tom geral desta análise de filme como sendo 'positivo', 'negativo' ou 'neutro'.",
    "Decida se a crítica abaixo expressa uma visão favorável ou desfavorável do filme.",
    "Analise o texto da crítica e determine se ela transmite um sentimento de aprovação ou desaprovação.",
    "Baseado na emoção expressa, indique se a seguinte resenha de filme é positiva, negativa ou neutra.",
    "Classifique a avaliação do filme como sendo predominantemente 'positiva', 'negativa' ou 'mista'.",
    "Determine a polaridade da crítica do filme: a opinião expressa é positiva ou negativa?",
    "Interprete o sentimento desta crítica e indique se o autor está elogiando ou criticando o filme.",
    "Analise o conteúdo emocional da crítica e classifique-a como 'favorável', 'desfavorável' ou 'imparcial'.",
]

# %%
# Parâmetros do experimento
dataset_path = settings["dataset_path"]
results_log_path = settings["results_log_path"]
models = settings["models"]
strategies = settings["strategies"]
top_k = settings["top_k"]

# %%
# Estratégias de prompting
def build_prompt(prompt_instruction, text, strategy):
    if strategy == "zero-shot":
        return f"{prompt_instruction}\n\nTexto: {text}\n\nResponda apenas com 0 (negativo) ou 1 (positivo)."
    elif strategy == "few-shot":
        examples = (
            "Texto: Esse filme é excelente, adorei cada momento.\nResposta: 1\n"
            "Texto: Que decepção! Perdi meu tempo assistindo.\nResposta: 0\n"
        )
        return f"{prompt_instruction}\n\n{examples}Texto: {text}\nResposta:"
    elif strategy == "cot":
        return (
            f"{prompt_instruction}\n\nTexto: {text}\n"
            f"Explique seu raciocínio antes de responder com 0 (negativo) ou 1 (positivo).\nResposta:"
        )

# %%
# GPT-4o Mini como gerador de prompts
def generate_prompt_with_gpt4o(top_prompts_with_scores):
    prompt_text = "\n".join([f"{i+1}. {p} (F1: {s:.2f})" for i, (p, s) in enumerate(top_prompts_with_scores)])
    system_instruction = "Você é um otimizador de prompts para classificação de sentimentos."
    user_instruction = (
        "Com base nos prompts abaixo e seus desempenhos, gere um novo prompt em português para a tarefa de "
        "classificação de sentimento (positivo ou negativo). Gere apenas o prompt:"
    )

    response = openai.ChatCompletion.create(
        model="gpt-4o",
        messages=[
            {"role": "system", "content": system_instruction},
            {"role": "user", "content": f"{user_instruction}\n\n{prompt_text}"}
        ],
        temperature=0.7,
    )
    return response.choices[0].message["content"].strip()

# %%
def query_maritalk(prompt_instruction, text):
    request_data = {
        "model": "sabiazinho-3",
        "messages": [{"role": "user", "content": f"{prompt_instruction}\n\nTexto: {text}"}]
    }

    try:
        response = requests.post(
            url=creds["sabia_url"],
            headers={
                "Authorization": f"Bearer {creds['sabia_api_key']}",
                "Content-Type": "application/json"
            },
            json=request_data,
            timeout=10
        )
        response.raise_for_status()
        prediction = response.json().get("answer", "").strip().lower()
        return prediction
    except requests.exceptions.RequestException as e:
        print(f"Erro na requisição para Maritalk: {e}")
        return "erro"

# %%
# Avaliação de um prompt
def evaluate_prompt(prompt_instruction, model, strategy):
    preds = []
    gold = df["label"].tolist()

    for text, true_label in zip(df["text"], gold):
        prompt = build_prompt(prompt_instruction, text, strategy)

        if model == "maritalk":
            response = query_maritalk(prompt_instruction, text)
        else:
            response = "0"  # mock para outros modelos

        if "1" in response:
            prediction = 1
        elif "0" in response:
            prediction = 0
        else:
            prediction = 1 - true_label
            print(f"Resposta inesperada: '{response}'")

        preds.append(prediction)

    return accuracy_score(gold, preds), f1_score(gold, preds)

# %%
# Execução de um cenário
def run_scenario(model, strategy, initial_prompts):
    results = []

    # Avalia prompts iniciais
    for prompt in initial_prompts:
        acc, f1 = evaluate_prompt(prompt, model, strategy)
        results.append((prompt, acc, f1))

    results.sort(key=lambda x: x[2], reverse=True)
    top_prompts = results[:top_k]

    # Salva resultado parcial inicial
    os.makedirs("logs", exist_ok=True)
    log_file = f"logs/results_{model}_{strategy}.csv"
    pd.DataFrame(results, columns=["prompt", "accuracy", "f1"]).to_csv(log_file, index=False)

    # Tenta gerar novos prompts com GPT-4o Mini
    try:
        new_prompts = [generate_prompt_with_gpt4o([(p, f1)]) for p, _, f1 in top_prompts]
    except Exception as e:
        print(f"Erro ao gerar prompts com GPT-4o Mini: {e}")
        new_prompts = []

    # Avalia novos prompts
    for prompt in new_prompts:
        acc, f1 = evaluate_prompt(prompt, model, strategy)
        results.append((prompt, acc, f1))

    # Salva resultados finais
    pd.DataFrame(results, columns=["prompt", "accuracy", "f1"]).to_csv(log_file, index=False)
    return results

# %%
# Executa os 9 cenários
final_results = []

for model in models:
    for strategy in strategies:
        print(f"Executando: {model} + {strategy}")
        scenario_results = run_scenario(model, strategy, initial_prompts)
        for prompt, acc, f1 in scenario_results:
            final_results.append({
                "model": model,
                "strategy": strategy,
                "prompt": prompt,
                "accuracy": acc,
                "f1": f1,
            })

# Salvamento geral
pd.DataFrame(final_results).to_csv(results_log_path, index=False)
# Out:
# Executando: maritalk + zero-shot
# Resposta inesperada: 'o sentimento desta crítica de filme é 'negativa'. a crítica contém várias expressões de descontentamento e decepção com o filme, destacando aspectos como os efeitos especiais (descritos como "roubo"), a história (questionada se realmente existiu), e a atuação (comparada de forma desfavorável a uma boneca). palavras como "decepcionado", "ridículo", "bagunça chata", "estúpido", "pior filme de terror", "má atriz", e "estúpido" reforçam a avaliação negativa. o tom geral é de desapontamento e descontentamento com o filme, classificando-o como uma má escolha tanto para os espectadores quanto para os críticos.'
# Resposta inesperada: 'esta crítica de filme pode ser classificada como 'negativa'. o texto expressa claramente desapontamento e insatisfação com a série, utilizando termos como "perda de tempo e dinheiro", "embaraçoso" e "horrível". além disso, compara negativamente a adaptação com o material original, o livro, e sugere que a série não fez justiça ao trabalho de bob ludlum.'
# Resposta inesperada: 'a avaliação de sentimento da crítica do filme pode ser considerada 'negativa'. apesar de o crítico reconhecer que o filme é 'assistível', ele faz diversas ressalvas e aponta vários problemas, como a combinação "inegavelmente indistinta" de referências de outros filmes, a presença de clichês que provocaram risos em vez de calafrios, e a falta de substância para os atores envolvidos. a frase "embora a maioria deles realmente não tenha nada" reforça a insatisfação com o roteiro e a utilização do elenco. portanto, o tom geral da crítica é de desapontamento e ceticismo em relação ao filme, o que caracteriza uma crítica negativa.'
# Resposta inesperada: 'a opinião expressa na crítica reflete um sentimento **negativo** sobre o filme. o crítico utiliza uma série de termos e expressões negativas para descrever a experiência de assistir ao filme. algumas das evidências de um sentimento negativo incluem:
#
# - "total decepcionado"
# - "o fato de as pessoas pensarem que este filme é assustador é ridículo"
# - "os efeitos especiais foram um roubo direto de 'the ring'"
# - "a história? houve uma? não na minha opinião... apenas um monte de imagens chamativas"
# - "o filme inteiro foi uma bagunça chata, estúpida"
# - "o pior filme de terror que já vi em anos"
# - "má atriz"
# - "tão plástico quanto barbie e tão talentoso... não, espere, isso seria um insulto aos talentos da barbie!"
# - "filme estúpido!"
#
# além disso, o crítico faz uma série de comparações depreciativas e expressa a opinião de que o filme só teve sucesso nas bilheterias devido a uma classificação inadequada e a uma campanha de marketing eficaz, o que reforça ainda mais o sentimento negativo.'
# Resposta inesperada: 'a opinião expressa na crítica reflete um sentimento negativo sobre a minissérie. o texto contém palavras e expressões de descontentamento como "chorado", "total perda de tempo e dinheiro", "embaraçoso", "horrível" e uma comparação negativa com o livro original, além de uma sugestão irônica para conferir uma versão anterior da série que, implicitamente, era melhor. esses elementos indicam claramente que o crítico não gostou da produção e a considera uma má representação das obras de bob ludlum.'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Resposta inesperada: 'o tom geral desta análise de filme é 'negativo'.'
# Resposta inesperada: 'negativo.
#
# o tom geral da análise do filme é predominantemente negativo. apesar de o autor reconhecer que o filme é "assistível", ele critica fortemente a previsibilidade e o uso de clichês, afirmando que o filme provoca risos em vez dos calafrios pretendidos. além disso, o autor faz uma observação sarcástica sobre a quantidade de estrelas atraídas devido à situação da indústria cinematográfica britânica na época, sugerindo que mesmo um roteiro medíocre foi capaz de reunir um elenco estelar. a expressão "embora a maioria deles realmente não tenha nada" reforça a impressão de que o filme não aproveita bem o talento dos atores. portanto, a análise contém mais elementos negativos do que positivos.'
# Resposta inesperada: 'a crítica expressa uma visão desfavorável do filme. o crítico demonstra desapontamento e insatisfação com a adaptação da mini série, comparando-a negativamente com o livro original. a frase "isso foi total perda de tempo e dinheiro" e a classificação "horrível" reforçam a opinião negativa, além disso, o crítico sugere que a versão original com richard chamberlain era melhor, o que indica que a atual não atendeu às suas expectativas.'
# Resposta inesperada: 'a crítica transmita um sentimento de desaprovação em relação à mini série. o uso de expressões como "chorado", "total perda de tempo e dinheiro", "embaraçoso", "pode ser o criador deveria [ter feito algo diferente]", e a exclamação "horrível!!" deixam claro que o crítico está desapontado com o resultado da adaptação para a televisão. a comparação com os livros de bob ludlum e a sugestão de que a série de tv era boa na época de richard chamberlain reforçam a ideia de que a atual versão não atendeu às expectativas do crítico.'
# Resposta inesperada: 'a resenha de filme é claramente negativa. o texto expressa decepção e desapontamento com vários aspectos do filme, incluindo os efeitos especiais, a história, a atuação dos atores e a percepção do público. palavras e frases como "total decepcionado", "ridículo", "roubo direto", "bagunça chata", "estúpida", "pior filme de terror", "má atriz", "plástico quanto barbie" e "filme estúpido" são usadas para enfatizar a avaliação negativa. além disso, a comparação com outros trabalhos e a expressão de opinião sobre o desempenho nas bilheterias reforçam a desaprovação do filme.'
# Resposta inesperada: 'a resenha de filme expressa claramente uma emoção negativa em relação à série. a utilização de termos como "chorado", "total perda de tempo e dinheiro", "embaraçoso", "horrível" e a comparação desfavorável com o livro original indicam que o resenhista teve uma experiência muito desapontadora ao assistir à série. portanto, a resenha é negativa.'
# Resposta inesperada: 'a resenha é negativa. o texto contém várias expressões que indicam desapontamento e crítica, como "combinação inegavelmente indistinta", "tão clichê que provou risadas em vez dos calafrios pretendidos", e "mesmo um roteiro medíocre". apesar de reconhecer que o filme é "assistível", o autor expressa que a atração do elenco estelar não compensa as falhas do roteiro e da execução do filme. a frase final, "embora a maioria deles realmente não tenha nada, me desculpe por dizer!", reforça a crítica ao elenco, indicando que muitos atores não têm papéis significativos ou são mal aproveitados.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'negativa'. o texto contém várias expressões críticas e negativas, como "total decepcionado", "ridículo", "roubo direto de 'the ring'", "não houve história", "bagunça chata e estúpida", "pior filme de terror que já vi em anos", "má atriz" e "filme estúpido". apesar de uma breve reflexão sobre a influência do marketing e a possibilidade de uma classificação etária impactar nas bilheterias, o tom geral é claramente negativo em relação ao filme.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'negativa'. o texto contém várias expressões negativas como "total perda de tempo e dinheiro", "a cbs perdeu tempo e dinheiro", "embaraçoso afirmar que esse era o trabalho de ludlum", e "horrível !!", que indicam insatisfação e desapontamento com a série. apesar de haver uma sugestão de algo positivo ao mencionar que a série de tv poderia ter sido boa com outro ator, o tom geral e a maioria das opiniões expressas são claramente negativos.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'mista'.
#
# o texto apresenta aspectos negativos como a premissa clichê e a falta de originalidade em comparação com outros filmes, que resultaram em risos ao invés de calafrios. porém, reconhece que o filme ainda é assistível, talvez devido à sua conexão com clássicos do cinema de terror. além disso, aponta o contexto da indústria cinematográfica britânica da época, que permitiu a reunião de um elenco de estrelas, o que pode ser visto como um ponto positivo. no entanto, o uso dos atores é criticado, com a maioria deles tendo pouco a fazer.
#
# em resumo, há reconhecimento de algumas qualidades e uma tentativa de contextualizar os defeitos, o que caracteriza uma avaliação mista.'
# Resposta inesperada: 'a crítica do filme é claramente negativa. o crítico expressa decepção e desapontamento com o filme desde o início. ele considera os efeitos especiais como uma cópia ruim de outro filme e questiona se houve alguma história. a descrição do filme como "chato" e "estúpido" reforça a impressão negativa. além disso, o crítico faz comentários depreciativos sobre a atuação principal, comparando-a de forma desfavorável a uma boneca, o que é evidentemente uma crítica severa. o crítico também sugere que o sucesso nas bilheterias se deve a um público infantil e à classificação etária, e não à qualidade do filme. em resumo, o texto é uma série de comentários negativos que destacam falhas e desapontamentos com o filme, classificando-o como o "pior filme de terror em anos".'
# Resposta inesperada: 'a crítica do filme é claramente negativa. o crítico expressa desapontamento e decepção com a adaptação da série, utilizando termos como "chorado", "total perda de tempo e dinheiro", "embaraçoso" e "horrível". a comparação com o livro original e a sugestão de que a escolha do ator richard chamberlain para o papel de bourne era melhor reforçam a insatisfação com a produção atual.'
# Resposta inesperada: 'o autor da crítica está claramente **criticando** o filme (neste caso, referindo-se a uma adaptação em série de tv). ele expressa profunda decepção e desapontamento, comparando negativamente a adaptação com o material original de bob ludlum. termos como "perda de tempo e dinheiro", "embaraçoso" e "horrível" reforçam a sua insatisfação. além disso, o autor sugere que uma escolha diferente de elenco poderia ter resultado em algo melhor, ao mencionar richard chamberlain como um ator mais adequado para o papel. o sentimento geral é de frustração e reprovação pela adaptação que, segundo ele, não fez jus ao trabalho original de ludlum.'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: maritalk + few-shot
# Resposta inesperada: 'o sentimento expresso nesta crítica de filme é 'negativo'. a avaliação contém uma série de adjetivos e expressões negativas, como "total decepcionado", "ridículo", "roubo direto", "bagunça chata e estúpida", "pior filme de terror", "má atriz", "plástico quanto barbie" e "filme estúpido". além disso, o crítico demonstra desapontamento com a qualidade do filme, os efeitos especiais e a atuação, e sugere que o sucesso do filme se deve a uma boa campanha de marketing e classificação inadequada. não há nada no texto que possa ser considerado positivo ou neutro; o tom é claramente de desaprovação e crítica.'
# Resposta inesperada: 'a crítica do filme é claramente **negativa**. o texto expressa profunda decepção e descontentamento com a adaptação da série de tv, descrevendo-a como uma "total perda de tempo e dinheiro" e adjetivando-a como "horrível". além disso, compara negativamente a produção original ao trabalho de bob ludlum e sugere que a cbs fez um mau uso dos recursos ao produzir algo que considera inferior ao livro original.'
# Resposta inesperada: 'a crítica do filme pode ser classificada como 'negativa'. o texto contém uma série de avaliações desfavoráveis sobre o filme, incluindo a comparação com outros filmes de uma maneira que sugere uma falta de originalidade ("combinação inegavelmente indistinta"), a afirmação de que o filme é repleto de clichês que provocaram risos ao invés de calafrios, e a menção de que o roteiro é medíocre. apesar de mencionar que o filme é "assistível" e reconhecer o elenco estrelado, a crítica é predominantemente negativa, destacando a falta de qualidade e impacto pretendido pela obra.'
# Resposta inesperada: 'a opinião expressa na crítica reflete um sentimento negativo sobre o filme. o crítico utiliza termos depreciativos e expressões de descontentamento ao longo de todo o texto. alguns exemplos são:
#
# - "total decepcionado"
# - "ridículo"
# - "roubo direto de 'the ring'"
# - "não houve história"
# - "bagunça chata, estúpida"
# - "o pior filme de terror que já vi em anos"
# - "má atriz"
# - "plástico quanto barbie" (como uma ofensa)
# - "filme estúpido"
#
# além disso, o crítico demonstra ceticismo quanto à qualidade do filme e sua recepção pelo público, atribuindo o sucesso nas bilheterias a uma classificação inadequada e a uma boa campanha de marketing. em resumo, o texto é uma crítica severa e negativa ao filme.'
# Resposta inesperada: 'a opinião expressa na crítica reflete um sentimento negativo sobre o filme. o crítico demonstra descontentamento e decepção com a adaptação, utilizando expressões como "chorado", "total perda de tempo e dinheiro", "embaraçoso" e "horrível". a comparação com o livro original é desfavorável e há uma sugestão de que uma escolha diferente de elenco poderia ter resultado em algo melhor. a exclamação "horrível" reforça a rejeição da produção pelo crítico.'
# Resposta inesperada: 'o tom geral desta análise de filme é 'negativo'. o autor expressa decepção e descontentamento com vários aspectos do filme, incluindo a qualidade dos efeitos especiais, a história, a atuação dos atores e a percepção do público. termos como "decepcionado", "ridículo", "roubo", "bagunça chata", "estúpido", "pior filme de terror", "má atriz", "plástico" e "estúpido" reforçam a opinião negativa do autor sobre o filme.'
# Resposta inesperada: 'o tom geral desta análise de filme é 'negativo'. o texto contém expressões fortemente negativas como "total perda de tempo e dinheiro", "embaraçoso afirmar que esse era o trabalho de ludlum", e "horrível !!", indicando claramente a insatisfação do autor com a adaptação do livro para a série de tv.'
# Resposta inesperada: 'o tom geral desta análise de filme é 'negativo'. o analista faz uma série de críticas ao filme, descrevendo-o como uma combinação clichê de outros filmes, incapaz de causar calafrios e, em vez disso, provocando risadas. ele reconhece que, apesar disso, o filme tem um elenco estelar devido a circunstâncias da indústria cinematográfica britânica da época, mas a maioria dos atores não tem muito o que fazer. o uso de termos como "clichê", "risadas em vez dos calafrios pretendidos" e a falta de papel substancial para os atores contribui para um tom predominantemente negativo.'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Resposta inesperada: 'a crítica expressa uma visão desfavorável do filme. o crítico expressa desapontamento e frustração, afirmando que a adaptação da série baseada no livro de bob ludlum foi uma "total perda de tempo e dinheiro". a comparação com o livro original é negativa, sugerindo que a série não conseguiu capturar o espírito do trabalho de ludlum. além disso, a expressão "horrível!!" no final reforça a opinião negativa sobre a produção.'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Resposta inesperada: 'o texto da crítica transmite um sentimento de desaprovação em relação ao filme. o crítico expressa decepção e descontentamento em várias passagens, destacando pontos específicos que considera negativos. termos como "decepcionado", "ridículo", "roubo", "bagunça chata", "estúpida" e "pior filme de terror" são usados para enfatizar a má qualidade do filme. além disso, o crítico faz uma comparação depreciativa entre a atriz e a boneca barbie, e sugere que o sucesso do filme se deve mais a uma boa campanha de marketing e classificação adequada para o público jovem do que a qualquer mérito próprio. no geral, a crítica é extremamente negativa.'
# Resposta inesperada: 'a crítica transmite um sentimento de desaprovação. o autor expressa frustração e decepção, utilizando termos como "total perda de tempo e dinheiro", "embaraçoso" e "horrível". além disso, a comparação com o trabalho original de bob ludlum é feita de forma negativa, sugerindo que a adaptação não fez jus ao material original. o uso de exclamação e a recomendação para conferir uma série anterior como exemplo de qualidade reforçam a desaprovação da mini série analisada.'
# Resposta inesperada: 'a crítica transmite um sentimento misto, mas predominantemente de desaprovação. apesar de reconhecer que o filme é "assistível em si", o crítico o descreve como uma combinação "inegavelmente indistinta" de referências a outros filmes e cheio de clichês. a reação do público, que riu em vez de sentir calafrios, reforça a percepção negativa do filme. a crítica também menciona que o roteiro é medíocre e que a presença de estrelas famosas não salva o filme, pois a maioria delas não tem nada de substancial para fazer. portanto, a desaprovação é clara, apesar de uma leve ressalva sobre a possibilidade de assistir ao filme.'
# Resposta inesperada: 'a resenha é claramente negativa. a linguagem utilizada é carregada de emoção negativa, com termos como "total decepcionado", "ridículo", "roubo", "bagunça chata e estúpida", "pior filme de terror", "má atriz", "plástico quanto barbie" e "filme estúpido". além disso, o autor expressa desapontamento com a história e os efeitos especiais, e faz comentários irônicos sobre a classificação indicativa do filme, sugerindo que o sucesso de bilheteria se deveu a um público mais jovem, menos exigente. a repetição de termos negativos e a frustração expressa em relação ao filme reforçam a natureza negativa da resenha.'
# Resposta inesperada: 'a resenha de filme é negativa. a linguagem utilizada, as expressões como "chorado", "total perda de tempo e dinheiro", "embaraçoso", "horrível" e a comparação desfavorável com o livro original indicam uma avaliação negativa da série.'
# Resposta inesperada: 'a resenha do filme é negativa. o autor expressa uma série de emoções negativas e críticas em relação ao filme. embora reconheça que o filme é "assistível" e mencione o elenco de estrelas, que poderia indicar um aspecto positivo, o tom predominante é de desapontamento e crítica. a comparação com outros filmes clássicos ("gaslight" e "les diaboliques") é feita para destacar o quão clichê e "inegavelmente indistinto" o filme é. o autor afirma que o filme provoca risos ao invés dos calafrios pretendidos, o que indica que as intenções do filme não foram alcançadas e que o resultado é insatisfatório. além disso, há um sarcasmo evidente ao mencionar o elenco de estrelas, sugerindo que, apesar do nome de grandes atores, a contribuição deles é quase nula para salvar o filme. portanto, com base nessa análise, a resenha é predominantemente negativa.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'negativa'. o texto contém inúmeros comentários negativos sobre o filme, incluindo a falta de uma história coerente, efeitos especiais pobres, atuações ruins e uma classificação inadequada que pode ter mascarado a qualidade ruim do filme. termos como "decepcionado", "ridículo", "bagunça chata", "pior filme de terror", "má atriz" e "filme estúpido" reforçam a natureza predominantemente negativa da avaliação.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'negativa'. o texto contém expressões como "perda de tempo e dinheiro", "embaraçoso", "horrível" e "total perda de tempo e dinheiro", indicando claramente a insatisfação do autor com a adaptação para a televisão. embora haja uma referência ao livro original e uma sugestão de comparação com uma série de tv anterior, a maior parte do texto é crítica, reforçando a classificação negativa.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'negativa'. apesar de haver um reconhecimento de que o filme é "assistível" e que a presença de um elenco estelar possa ser considerada um ponto positivo, o texto destaca que o filme é repleto de clichês que provocaram risos ao invés de calafrios, o que sugere que a intenção assustadora ou dramática foi perdida. além disso, a crítica sugere que o roteiro é medíocre e que a maioria dos atores não tem muito o que fazer, o que contribui para uma avaliação geral negativa.'
# Resposta inesperada: 'a crítica do filme é claramente negativa. o crítico expressa decepção e desapontamento com o filme em várias passagens, chamando-o de "ridículo", "bagunça chata" e "estúpido". ele critica os efeitos especiais, afirmando que foram "roubados" de outro filme, questiona a existência de uma história coerente, e descreve a atuação da protagonista como "plástica" e "sem talento". o crítico também sugere que o filme foi impulsionado por uma boa campanha de marketing e uma classificação que atraiu um público mais jovem, insinuando que, se o filme tivesse uma classificação mais restritiva, teria fracassado nas bilheterias. em resumo, o tom geral da crítica é fortemente negativo, com o crítico demonstrando clara aversão ao filme.'
# Resposta inesperada: 'o autor está claramente criticando o filme. o tom geral da crítica é de decepção e descontentamento. ele expressa incredulidade que as pessoas considerem o filme assustador, acha que os efeitos especiais são uma cópia ruim de outro filme ("the ring"), e questiona se há uma história de fato. além disso, o autor classifica o filme como uma "bagunça chata, estúpida", e o pior filme de terror que já viu em anos. ele também critica a atuação principal, comparando a atriz a uma barbie, o que, em sua opinião, seria um insulto aos talentos da própria barbie. por fim, o autor sugere que o sucesso nas bilheterias se deve a uma classificação inadequada e a uma campanha de marketing eficiente, mas ainda assim, considera o filme estúpido.'
# Resposta inesperada: 'o autor está criticando fortemente a adaptação da série baseada nos livros de bob ludlum. o tom negativo é evidente pelas expressões "chorado", "total perda de tempo e dinheiro", "embaraçoso", e "horrível". a comparação com o trabalho original de ludlum é feita de maneira depreciativa, sugerindo que a série não faz jus à qualidade e ao legado do autor. além disso, o autor expressa nostalgia e preferência pela série de tv original com richard chamberlain, insinuando que essa versão era superior. portanto, o sentimento do texto é de descontentamento e crítica à adaptação recente.'
# Resposta inesperada: 'a crítica analisada é claramente **desfavorável**. o crítico expressa decepção e desapontamento ao longo de todo o texto, usando termos pejorativos e frases negativas para descrever o filme. algumas evidências da natureza desfavorável da crítica incluem:
#
# - "uau, que total decepcionado!"
# - "o fato de as pessoas pensarem que este filme é assustador é ridículo."
# - "os efeitos especiais foram um roubo direto de 'the ring'."
# - "a história? houve uma? não na minha opinião... apenas um monte de imagens chamativas."
# - "o filme inteiro foi uma bagunça chata, estúpida."
# - "eu acho que sempre há um mercado para filmes ruins com boas campanhas de marketing. no entanto, este é o pior filme de terror que já vi em anos."
# - "e aquela garota de buffy? bem, ela é uma má atriz!"
# - "tão plástico quanto barbie e tão talentoso... não, espere, isso seria um insulto aos talentos da barbie!"
# - "suponho que muitas crianças ajudaram esse filme nas bilheterias..."
# - "filme estúpido!"
#
# o tom da crítica é carregado de frustração, descontentamento e sarcasmo, reforçando a classificação como desfavorável.'
# Resposta inesperada: 'a crítica apresentada é claramente **desfavorável**. o autor expressa profunda decepção e descontentamento com a série analisada, destacando a perda de tempo e dinheiro envolvida na produção. a comparação com o livro original e a referência ao criador bob ludlum são utilizadas para enfatizar quão longe o resultado final está da expectativa. o uso de exclamações e expressões como "choraria", "total perda de tempo e dinheiro", "embaraçoso" e "horrível" reforçam o tom negativo da avaliação.'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: maritalk + cot
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Resposta inesperada: 'a opinião expressa na crítica reflete um sentimento negativo sobre o filme. o crítico utiliza várias expressões e palavras de conotação negativa para descrever suas impressões sobre o filme. algumas dessas expressões incluem:
#
# - "total decepcionado"
# - "ridículo"
# - "roubo direto de 'the ring'" (indicando falta de originalidade)
# - "não houve história"
# - "monte de imagens chamativas" (de maneira pejorativa)
# - "bagunça chata, estúpida"
# - "pior filme de terror que já vi em anos"
# - "má atriz"
# - "plástico quanto barbie" (como um insulto)
# - "teria bombardeado" (se tivesse uma classificação mais alta)
# - "filme estúpido!"
#
# o crítico manifesta insatisfação em praticamente todos os aspectos do filme, incluindo a história, os efeitos especiais, o desempenho da atriz e a classificação indicativa. portanto, é evidente que a crítica é extremamente negativa.'
# Resposta inesperada: 'a opinião expressa na crítica reflete um sentimento negativo sobre o filme. o crítico expressa desapontamento e frustração, destacando a perda de tempo e dinheiro, além de considerar a adaptação como uma desonra ao trabalho original de bob ludlum. termos como "total perda de tempo e dinheiro", "embaraçoso", e "horrível" reforçam a avaliação negativa da mini série.'
# Resposta inesperada: 'o tom geral desta análise de filme é 'negativo'. o texto está repleto de críticas fortes e expressões de descontentamento em relação ao filme, como "total decepcionado", "ridículo", "roubo direto de 'the ring'", "bagunça chata, estúpida", "pior filme de terror que já vi em anos", e "má atriz". além disso, o autor expressa frustração com o sucesso do filme nas bilheterias, atribuindo-o a uma classificação inadequada. o uso de exclamações e a repetição de palavras negativas reforçam o tom negativo da crítica.'
# Resposta inesperada: 'o tom geral desta análise de filme é 'negativo'. a avaliação contém expressões de desapontamento e decepção, como "chorado", "total perda de tempo e dinheiro", "embaraçoso", "horrível", e comparações negativas com o livro original, sugerindo que a adaptação não atingiu os padrões esperados.'
# Resposta inesperada: 'o tom geral desta análise de filme pode ser classificado como 'negativo'. apesar de o texto reconhecer que o filme conseguiu atrair um elenco de peso, a avaliação é predominantemente crítica, destacando o roteiro como medíocre e a trama como excessivamente clichê, incapaz de provocar os calafrios pretendidos e resultando em risadas ao invés de suspense. termos como "indistinto", "clichê" e "apuros" da indústria para justificar o elenco reforçam a natureza negativa da análise.'
# Resposta inesperada: 'a crítica expressa uma visão desfavorável do filme. o crítico utiliza termos como "total decepcionado", "ridículo", "roubo", "bagunça chata", "estúpida", "pior filme de terror", "má atriz", "plástico quanto barbie" (com o acréscimo de que isso seria um insulto à barbie, o que sugere que a atriz não tem talento), e "filme estúpido". além disso, o crítico questiona a qualidade da história e dos efeitos especiais, sugere que o sucesso do filme se deve a uma boa campanha de marketing e a uma classificação indicativa que atraiu um público específico, e não à qualidade do filme em si.'
# Resposta inesperada: 'a crítica expressa uma visão desfavorável do filme. o autor do texto demonstra grande desapontamento com a adaptação do livro para a minissérie, sugerindo que foi uma perda de tempo e dinheiro. ele menciona que ficaria desapontado o próprio autor do livro, bob ludlum, ao ver a série, e que a cbs errou ao associar o nome de ludlum a uma produção que considera de baixa qualidade. a comparação com uma possível versão estrelada por richard chamberlain serve para reforçar a ideia de que a série original poderia ter sido melhor. o uso de exclamações e a expressão "horrível!!" são indícios claros de descontentamento.'
# Resposta inesperada: 'a crítica expressa uma visão desfavorável do filme. o crítico faz uma comparação irônica da premissa do filme com outras obras e sugere que o filme é uma combinação "inegavelmente indistinta" de referências a "gaslight" e "les diaboliques". ele considera o filme cheio de clichês que provocam risadas em vez de calafrios, o que indica uma decepção quanto ao gênero de terror ou suspense ao qual o filme pertence.
#
# apesar de reconhecer que o filme é "assistível em si", o crítico é cético em relação à qualidade do roteiro, que ele descreve como "mediocre". a menção do contexto da indústria cinematográfica britânica da época, que teria permitido a reunião de um elenco estelar, serve como um contraste para destacar o desperdício de talentos diante de um roteiro fraco. o uso da frase "embora a maioria deles realmente não tenha nada" reforça a ideia de que o elenco, apesar de famoso, não consegue salvar o filme.
#
# portanto, a crítica é predominantemente desfavorável, com alguns pontos positivos sendo levantados de maneira irônica ou sarcástica.'
# Resposta inesperada: 'a crítica transmite um sentimento de desaprovação em relação ao filme. o autor expressa frustração e decepção, utilizando palavras e frases como "total decepcionado", "ridículo", "roubo", "bagunça chata, estúpida", "pior filme de terror que já vi em anos", e "má atriz". além disso, o tom sarcástico e as comparações depreciativas reforçam a opinião negativa sobre o filme e sua atriz. a afirmação de que o filme só teve sucesso nas bilheterias devido à classificação etária e a campanha de marketing também denota ceticismo quanto à qualidade do filme.'
# Resposta inesperada: 'a crítica transmite um sentimento de desaprovação em relação à minissérie. o autor expressa decepção e descontentamento, mencionando que a adaptação da obra original foi uma "perda de tempo e dinheiro". além disso, a comparação com o livro original e a sugestão de que uma escolha diferente de elenco poderia ter salvado a série ("confira a identidade de bourne com richard chamberlain e veja como a série de tv era boa") reforça a insatisfação. a exclamação "horrível!!" no final reforça ainda mais o desagrado do crítico com a produção.'
# Resposta inesperada: 'o texto transmite um sentimento de desaprovação em relação ao filme. o crítico faz comparações com clássicos do gênero (gaslight e les diaboliques), mas considera que o filme não consegue alcançar o mesmo impacto, sendo apenas "assistível" e repleto de clichês que geraram risos ao invés de calafrios. a crítica também ironiza a quantidade de estrelas no elenco, apontando que, apesar disso, a maioria dos atores não tem muito o que fazer no filme. a expressão "me desculpe por dizer!" reforça o tom negativo, indicando que o que será dito a seguir confirma a mediocridade do filme.'
# Resposta inesperada: 'a resenha de filme expressa uma emoção claramente negativa. o texto está repleto de expressões de descontentamento e decepção, como "total decepcionado", "ridículo", "roubo direto", "bagunça chata", "estúpida", "pior filme de terror", "má atriz" e "plástico quanto barbie". além disso, o autor da resenha faz comparações desfavoráveis, usa exclamações para enfatizar sua frustração e insatisfação, e expressa uma opinião negativa sobre a bilheteria do filme com base na classificação etária. a repetição de palavras como "estúpido" e a frase "filme estúpido!" reforçam a natureza negativa da resenha.'
# Resposta inesperada: 'a resenha é negativa. o texto expressa decepção e descontentamento com a adaptação da série baseada nos livros de bob ludlum. palavras como "chorado", "total perda de tempo e dinheiro", "embaraçoso", "horrível" e a comparação desfavorável com o livro original e outra série de tv reforçam a avaliação negativa.'
# Resposta inesperada: 'a resenha do filme é predominantemente negativa. o autor destaca a combinação "inegavelmente indistinta" de referências a outros filmes, a previsibilidade e o uso de clichês que resultaram em risos ao invés de calafrios, o que indica uma decepção com a proposta de terror ou suspense do filme. apesar de reconhecer que o filme é "assistível em si", a crítica aponta para a mediocridade do roteiro e o uso excessivo de estrelas que não adicionam substância ao filme. a parte final do texto, que inclui um pedido de desculpas por ser sincero, reforça o tom negativo da avaliação, mostrando que o autor não poupa comentários desfavoráveis.'
# Resposta inesperada: 'a avaliação do filme é predominantemente **negativa**. o texto contém várias expressões críticas e comentários depreciativos sobre o filme, incluindo a comparação dos efeitos especiais, questionamento da existência de uma história coerente, descrição do filme como uma "bagunça chata, estúpida", crítica à atriz principal e à classificação etária do filme. apenas uma breve menção sobre a possibilidade de boas campanhas de marketing suportarem filmes ruins não altera o tom geral negativo do comentário.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'negativa'. o texto contém expressões fortemente críticas como "total perda de tempo e dinheiro", "perdeu tempo e dinheiro", "embaraçoso", "horrível", e sugere que a adaptação não fez justiça ao trabalho original de bob ludlum. embora haja uma menção ao livro, o foco da crítica é claramente negativo em relação à série.'
# Resposta inesperada: 'a avaliação do filme é predominantemente 'mista'. o texto contém elementos tanto positivos quanto negativos. a combinação de referências a clássicos do cinema e a tentativa de criar uma história de suspense são reconhecidas, mas o filme é criticado por ser excessivamente clichê e não conseguir provocar os calafrios desejados, resultando em risos ao invés de tensão. apesar disso, há uma aparente tentativa de defender o filme devido ao contexto da indústria cinematográfica britânica da época e a presença de um elenco estelar. o elenco é mencionado de forma irônica, destacando que muitos atores tiveram pouca importância no filme. assim, a avaliação oscila entre reconhecer o esforço e contexto e apontar falhas significativas na execução.'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Erro na requisição para Maritalk: HTTPSConnectionPool(host='chat.maritaca.ai', port=443): Read timed out. (read timeout=10)
# Resposta inesperada: 'erro'
# Resposta inesperada: 'o autor está claramente criticando a mini série. ele expressa desapontamento e frustração com o resultado da adaptação para a tv, comparando-a de maneira negativa tanto ao livro original de bob ludlum quanto a uma versão anterior estrelada por richard chamberlain. a frase "choraria" é usada ironicamente, indicando tristeza pelo que considera uma total perda de tempo e dinheiro. o uso de exclamações e termos como "perda de tempo", "embaraçoso" e "horrível" reforçam o descontentamento do autor com a série, deixando claro que ele não aprovou a adaptação.'
# Resposta inesperada: 'o autor está criticando o filme. apesar de reconhecer que o conceito de um fantasma vingativo poderia ser irônico e de admitir que o filme é "assistível em si", a crítica é predominantemente negativa. o autor acha que o filme é uma combinação "inegavelmente indistinta" de referências a outros filmes ("gaslight" e "les diaboliques") e que, em vez de provocar calafrios, o filme conseguiu arrancar risadas devido à sua previsibilidade e uso de clichês.
#
# além disso, embora o autor reconheça a presença de um elenco estelar, ele considera que muitos atores não têm material significativo para trabalhar, o que é dito de forma irônica com um pedido de desculpas pela sinceridade da crítica. o tom geral é de desapontamento e desdém pela qualidade do roteiro e da execução do filme.'
# Resposta inesperada: 'a crítica apresentada é claramente 'desfavorável'. o crítico expressa decepção e descontentamento em relação ao filme em vários aspectos, incluindo a qualidade dos efeitos especiais, a falta de uma história coerente, a qualidade da atuação, e a relação entre o conteúdo do filme e sua classificação etária. a linguagem usada é repleta de emoções negativas, como decepção, ridículo, roubo, bagunça chata, estúpido, má atuação e insulto. o crítico também compara a atriz ao boneco de plástico barbie, o que é uma crítica severa à sua performance. a frase "o pior filme de terror que já vi em anos" é uma afirmação clara da desaprovação extrema do filme. portanto, não há imparcialidade ou favorabilidade no texto, apenas um ponto de vista negativo e desaprovador.'
# Resposta inesperada: 'a crítica analisada é desfavorável. o texto expressa claramente desapontamento e insatisfação com a série em questão. termos como "chorado", "total perda de tempo e dinheiro", "embaraçoso", e a comparação negativa com o livro original, além da exclamação "horrível!!", reforçam a avaliação negativa. a comparação com o trabalho original de bob ludlum e a sugestão de que a escolha do ator não foi apropriada também contribuem para o tom desfavorável da crítica.'
# Resposta inesperada: 'a crítica apresentada pode ser classificada como 'desfavorável'.
#
# o crítico usa um tom sarcástico e irônico ao descrever o filme como uma combinação "inegavelmente indistinta" de outros clássicos do cinema, indicando falta de originalidade. além disso, ele menciona que o filme provoca risadas ao invés dos "calafrios pretendidos", evidenciando que as intenções do filme não foram alcançadas. embora reconheça que o filme é "assistível", ele é dominado por clichês e o roteiro é considerado medíocre. o elenco estelar é mencionado de forma cética, destacando que, apesar de ter nomes conhecidos, a maioria não tem muito a fazer no filme. esses elementos todos contribuem para uma análise negativa do filme.'
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: deepseek + zero-shot
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: deepseek + few-shot
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: deepseek + cot
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: llama + zero-shot
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: llama + few-shot
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`
# Executando: llama + cot
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /home/sara/repos/emo-prompt-project/.venv/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Erro ao gerar prompts com GPT-4o Mini: Project `proj_PY18Vj5USyoF6IAj2IPID8Fi` does not have access to model `gpt-4o`

# %% [markdown]
# ## Funções Auxiliares

# %% [markdown]
# ## Avaliação Final

# %%
# Avaliação final
best_prompt = population[0]
final_accuracy = sum(
    evaluate_prompt(example['text'], best_prompt, example['label'], url, headers)
    for example in test_sample
) / len(test_sample)
logging.info(f"Melhor prompt: {best_prompt}")
logging.info(f"Acurácia final no conjunto de teste: {final_accuracy:.2%}")
print(f"Melhor prompt: {best_prompt}")
print(f"Acurácia final no conjunto de teste: {final_accuracy:.2%}")
